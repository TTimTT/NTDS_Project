# %% [markdown]
# # [NTDS'18] milestone 2: network models
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Hermina Petric Maretic](https://people.epfl.ch/hermina.petricmaretic), [EPFL LTS4](https://lts4.epfl.ch)

# %% [markdown]
# ### Students
#
# * Team: `30`
# * Students: `Tim Tuuva, Lucas Biotto, Anael Buchegger,Joachim Tapparel`
# * Dataset: `Free Music Archive`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * In the first part, you cannot import any other library than we imported. In the second part, you are allowed to import any library you want.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The purpose of this milestone is to explore various random network models, analyse their properties and compare them to your network. In the first part of the milestone you will implement two random graph models and try to fit them to your network. In this part you are not allowed to use any additional package. In the second part of the milestone you will choose a third random graph model that you think shares some properties with your network. You will be allowed to use additional packages to construct this network, but you must explain your network choice. Finally, make your code as clean as possible, and keep your textual answers short.

# %% [markdown]
# ## Part 0
#
# Import the adjacency matrix of your graph that you constructed in milestone 1, as well as the number of nodes and edges of your network.

# %%
import numpy as np # we need it to load adjacency
adjacency = np.load('../data/fma_metadata/adjacency.npy') # the adjacency matrix
n_nodes = adjacency.shape[0]  # the number of nodes in the network
n_edges =  (sum(sum(np.ceil(adjacency))))/2 # the number of edges in the network

# %% [markdown]
# ## Part 1
#
# **For the computation of this part of the milestone you are only allowed to use the packages that have been imported in the cell below.**

# %%
# %matplotlib inline

import random
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ### Question 1
#
# Create a function that constructs an Erdős–Rényi graph.

# %%
def erdos_renyi(n, p, seed=None):
    """Create an instance from the Erdos-Renyi graph model.
    
    Parameters
    ----------
    n: int
        Size of the graph.
    p: float
        Edge probability. A number between 0 and 1.
    seed: int (optional)
        Seed for the random number generator. To get reproducible results.
    
    Returns
    -------
    adjacency
        The adjacency matrix of a graph.
    """
    # Use the seed if provided
    np.random.seed(seed)
    
    # Binarise Matrix Function:
    binarise = lambda x: 1 if(x < p) else 0
    binarise = np.vectorize(binarise)
    
    # Create a Matrix with random numbers
    a = binarise(np.random.rand(n,n))
    
    # Take the upper part and symmetrize
    a = np.tril(a, -1).T
    adjacency = a + a.T
    
    return adjacency

# %%
er = erdos_renyi(5, 0.6, 9765)
plt.spy(er)
plt.title('Erdos-Renyi (5, 0.6)')
# Out:
# Text(0.5, 1.05, 'Erdos-Renyi (5, 0.6)')

# %%
er = erdos_renyi(10, 0.4, 7648)
plt.spy(er)
plt.title('Erdos-Renyi (10, 0.4)')
# Out:
# Text(0.5, 1.05, 'Erdos-Renyi (10, 0.4)')

# %% [markdown]
# ### Question 2
#
# Use the function to create a random Erdos-Renyi graph. Choose the parameters such that number of nodes is the same as in your graph, and the number of edges similar. You don't need to set the random seed. Comment on your choice of parameters.

# %%
er = erdos_renyi(1988, 0.1265,0)
n_edges_er =  (sum(sum(er)))/2 # the number of edges in the network
print('real network edges:',n_edges,'\nerdos renyi edges:',n_edges_er)
# Out:
# real network edges: 250493.0
# erdos renyi edges: 249452.0

# %% [markdown]
# **By setting the probability of connection to our sparsity ratio (Milestone 1), we obtain roughly the expected number of connections.**

# %% [markdown]
# ### Question 3
#
# Create a function that constructs a Barabási-Albert graph.

# %%
def barabasi_albert(n, m, m0=2, seed=None):
    """Create an instance from the Barabasi-Albert graph model.
    
    Parameters
    ----------
    n: int
        Size of the graph.
    m: int
        Number of edges to attach from a new node to existing nodes.
    m0: int (optional)
        Number of nodes for the inital connected network.
    seed: int (optional)
        Seed for the random number generator. To get reproducible results.
    
    Returns
    -------
    adjacency
        The adjacency matrix of a graph.
    """
    if seed:
        np.random.seed(seed)
    
    adjacency=np.zeros([n,n])
      
    if m>m0:
        m0=m
    #initial state (everything connected)
    for i in range(0,m0):
        adjacency[i,0:m0]=1
        adjacency[i,i]=m0-1 #store the node degree on the diag
        deg_tot=m0*(m0-1)
        
    prob=np.zeros(n) # probability of connection to each node       
    # for each new node
    for i in range(m0,n): 
        #create the probability vector
        for k in range(0,i):
            prob[k]= adjacency[k,k]/deg_tot;
            
        #choose the nodes to connect the new one and connect them
        new_links=np.random.choice(i,m,replace=False,p=prob[0:i])
        for k in new_links:
            adjacency[i,k]=1
            adjacency[k,i]=1
            adjacency[k,k]+=1
            adjacency[i,i]+=1
            deg_tot+=2

    #remove the node degree used to create the network                
    np.fill_diagonal(adjacency, 0)
    
    return adjacency

# %%
ba = barabasi_albert(5, 1, 2, 9087)
plt.spy(ba)
plt.title('Barabasi-Albert (5, 1)')
# Out:
# Text(0.5, 1.05, 'Barabasi-Albert (5, 1)')

# %%
ba = barabasi_albert(10, 2, 3, 8708)
plt.spy(ba)
plt.title('Barabasi-Albert (10, 2)')
# Out:
# Text(0.5, 1.05, 'Barabasi-Albert (10, 2)')

# %% [markdown]
# ### Question 4
#
# Use the function to create a random Barabási-Albert graph. Choose the parameters such that number of nodes is the same as in your graph, and the number of edges similar. You don't need to set the random seed. Comment on your choice of parameters.

# %%
ba = barabasi_albert(1988, 130)
n_edges_ba =  (sum(sum(ba)))/2 # the number of edges in the network
print('real network edges:',n_edges,'\nBarabasi-Albert edges:',n_edges_ba)
# Out:
# real network edges: 250493.0
# Barabasi-Albert edges: 249925.0

# %%
plt.figure(figsize=(15, 15))
plt.spy(ba)
plt.title('Barabasi-Albert')
# Out:
# Text(0.5, 1.05, 'Barabasi-Albert')

# %% [markdown]
# **Since our network has 1988 nodes, we need to create ~130 edge per node in order to get ~250'000 edges.**

# %% [markdown]
# ### Question 5
#
# Compare the number of edges in all three networks (your real network, the Erdős–Rényi network, and the Barabási-Albert network).

# %%
print('Real network edges:',n_edges,'\nErdos-Renyi edges:',n_edges_er,'\nBarabasi-Albert edges:',n_edges_ba)
# Out:
# Real network edges: 250493.0
# Erdos-Renyi edges: 249452.0
# Barabasi-Albert edges: 249925.0

# %% [markdown]
# ### Question 6
#
# Implement a function that computes the [Kullback–Leibler (KL) divergence](https://en.wikipedia.org/wiki/Kullback%E2%80%93Leibler_divergence) between two probability distributions.
# We'll use it to compare the degree distributions of networks.

# %%
def kl_divergence(p, q):
    """Compute the KL divergence between probability distributions of degrees of two networks.
    
    Parameters
    ----------
    p: np.array
        Probability distribution of degrees of the 1st graph.
    q: np.array
        Probability distribution of degrees of the 2nd graph.
    
    Returns
    -------
    kl
        The KL divergence between the two distributions.
    """
    kl=0;
    for i in range(0,p.shape[0]):
        if q[i] and p[i]: #ensure none null division or log(0)        
            kl += (p[i]*np.log(p[i]/q[i]));
               
    return kl

# %%
p_test = np.array([0.2, 0.2, 0.2, 0.4])
q_test = np.array([0.3, 0.3, 0.1, 0.3])
kl_divergence(p_test, q_test)
# Out:
# 0.09151622184943575

# %% [markdown]
# ### Question 7:
#
# Compare the degree distribution of your network to each of the two synthetic ones, in terms of KL divergence.
#
# **Hint:** Make sure you normalise your degree distributions to make them valid probability distributions.
#
# **Hint:** Make sure none of the graphs have disconnected nodes, as KL divergence will not be defined in that case. If that happens with one of the randomly generated networks, you can regenerate it and keep the seed that gives you no disconnected nodes.

# %%
def remove_isolated_nodes(adjacency):
    # Remove line full of 0
    matrix = adjacency[~np.all(adjacency == 0, axis=1)]
    
    # Remove column full of 0
    matrix = matrix.T[~np.all(matrix.T == 0, axis=1)]
    
    return matrix

# %%
adjacency_con=remove_isolated_nodes(adjacency)

# %%
def degree_distrib(adjacency):
    #return the degree distribution of an adjacency matrix
    degrees=sum(np.ceil(adjacency))

    deg_distr=np.zeros(adjacency_con.shape[0])

    for i in range(0,adjacency_con.shape[0]):   
        deg_distr[int(degrees[i])]+=1

    #normalization
    deg_distr/=sum(deg_distr)

    return deg_distr

# %%
orig_deg_dist=degree_distrib(adjacency_con)
er_deg_dist=degree_distrib(er)
ba_deg_dist=degree_distrib(ba)
print('KL divergence of original and ER network=',kl_divergence(er_deg_dist,orig_deg_dist))
print('KL divergence of original and BA network=',kl_divergence(ba_deg_dist,orig_deg_dist))
# Out:
# KL divergence of original and ER network= 2.2890184992409788
# KL divergence of original and BA network= 0.9161533520836787

# %% [markdown]
# ### Question 8
#
# Plot the degree distribution historgrams for all three networks. Are they consistent with the KL divergence results? Explain.

# %%
plt.rcParams['figure.figsize'] = [12, 10]

weights = np.ones_like(sum(np.ceil(adjacency_con))) / float(n_nodes)
plt.hist(sum(np.ceil(adjacency_con)),40, weights=weights,histtype='step')

weights2 = np.ones_like(sum(np.ceil(er))) / float(n_nodes)
plt.hist(sum(np.ceil(er)), weights=weights2,histtype='step')

weights3 = np.ones_like(sum(np.ceil(ba))) / float(n_nodes)
plt.hist(sum(np.ceil(ba)),40, weights=weights3,histtype='step')

plt.legend(['Original','Erdös-Rényi','Barabási-Albert'],prop={'size': 14})
plt.show()

# %% [markdown]
# **As the KL divergence tells us, the BA distribution is a better fit for our real distribution (lower value). We impose at least 130 edges per node in the BA distribution but it might give better results if we didn't specify a strict number of links**

# %% [markdown]
# ### Question 9
#
# Imagine you got equal degree distributions. Would that guarantee you got the same graph? Explain.

# %% [markdown]
# **No, it would mean that the same *number* of nodes have the same corresponding degree, not that these nodes are the same between the two graphs. Moreover, the degree of a node doesn't tell us to which other nodes our target is connected, and they could thus be different**

# %% [markdown]
# ## Part 2
#
# **You are allowed to use any additional library here (e.g., NetworkX, PyGSP, etc.).** Be careful not to include something here and use it in part 1!

# %% [markdown]
# ### Question 10
#
# Choose a random network model that fits you network well. Explain your choice.
#
# **Hint:** Check lecture notes for different network models and their properties. Your choice should be made based on at least one property you'd expect to be similar.

# %% [markdown]
# **We tried to match the degree distribution. That lead us toward a powerlaw distribution. We choosed a powerlaw_cluster_graph which is a variant of the BA model.**

# %% [markdown]
# ### Question 11
#
# Explain (in short) how the chosen model works.

# %% [markdown]
# **It is a variant of the BA model which adds, with a certain probability, the possibility to choose another node after the creation of an edge and make a triangle with it. By creating this triangles, we spread the degree distribution which leads to a better fit of our model**

# %% [markdown]
# ### Question 12
#
# Create a random graph from that model, such that the number of nodes is the same as in your graph.

# %%
import networkx as nx
G= nx.powerlaw_cluster_graph(1988, 70, 0.5)

# %% [markdown]
# ### Question 13
#
# Check the properties you expected to be similar, and compare to your network.

# %%
adja_approx=nx.to_numpy_matrix(G)
adja_approx=np.array(adja_approx)

deg_dist_approx=degree_distrib(adja_approx)

plt.rcParams['figure.figsize'] = [12, 10]
weights = np.ones_like(sum(np.ceil(adjacency_con))) / float(n_nodes)
plt.hist(sum(np.ceil(adjacency_con)),20, weights=weights,histtype='step')

weights = np.ones_like(deg_dist_approx) / float(1988)
plt.hist(sum(adja_approx),20,log=True,weights=weights,histtype='step')

plt.show()
print('KL divergence=',kl_divergence(deg_dist_approx,orig_deg_dist))
print('Number of edges:',sum(sum(adja_approx))/2)
# Out:
# KL divergence= 1.383766136673556
# Number of edges: 132274.0

# %% [markdown]
# Are the results what you expected? Explain.

# %% [markdown]
# **The results are not really what was expected since we get a worse KL divergence than with the simple BA model. And even if visually this distribution suits better, we get a graph with fewer edges (around half of them). Ideally we would like to have a model that has a constant degree distibution between 0 and 600 edges.**
