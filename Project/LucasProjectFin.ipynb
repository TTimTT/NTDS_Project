# %%
#import libraries
import numpy as np
import pandas as pd
import networkx as nx
from scipy import sparse
import scipy.sparse.linalg
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist, squareform
from pygsp import graphs, filters

# %%
# %matplotlib inline
import seaborn
plt.style.use('seaborn')#switch to seaborn style# TODO
seaborn.set_style(style='white')

# %%
tracks = pd.read_csv('data/tracks.csv', index_col=0, header=[0, 1]);
#load and normalize features
features= pd.read_csv('data/features.csv', index_col=0, header=[0, 1, 2])
dfmax=abs(features).max()
features=features.divide(dfmax)

genres=pd.read_csv('data/genres.csv', index_col=0, header=[0])

# %%
# Keep only the genre for each track
label=pd.DataFrame({('label','genre','main'): tracks['track']['genre_top'],
                    ('label','genre','sub'): tracks['track']['genres']})

# Keep on the tracks from small subset
label = label[tracks['set','subset'] == 'small']


# Keep only the genres we want
genre_list = ['Rock','Folk','Hip-Hop']#['Hip-Hop', 'Folk',Rock','Jazz','Classical','Pop','Electronic']
label = label[label['label']['genre']['main'].isin(genre_list)]

#add sub genres
genres_dict=genres['title'].to_dict()
genres_dict={str(key):genres_dict[key] for key in genres_dict}

label['label']['genre']['sub']=label['label']['genre']['sub'].str.replace('[^0-9| ]','').str.split(' ').apply(lambda x:'|'.join([genres_dict[k] for k in x ]))


# Merging
dataSet = features.merge(label, left_index=True, right_on='track_id')
#dataSet=dataSet.sort_values([('label', 'genre','main')])

# %%
print(sum(dataSet.label.genre.main=='Rock'))
label.label.genre.main.unique()
# Out:
# 1000
# array(['Hip-Hop', 'Folk', 'Rock'], dtype=object)

# %%
#we calculate the distances of our dataset
distances = pdist(dataSet.drop(columns='label',level=0).values, metric='euclidean')

# %%
#We calculate the weights of our adjacency matrix
kernel_width = distances.mean()
weights = np.exp(-distances**2 / kernel_width**2)
adjacency_full = squareform(weights)

# %%
# np.save("data/adjacency_HRJC.npy",adjacency_full)

# %%
# adjacency_full=np.load("data/adjacency_HRJC.npy")

# %%
plt.hist(weights)
plt.title('Distribution of weights')
plt.xlabel('Weights of links')
plt.show()

# %%
#informatons over connectivity of main component 
adjacency=adjacency_full.copy() #we keep the original adjacency matrix
adjacency[adjacency < 0.65] = 0
graph=nx.from_numpy_matrix(adjacency)
print("#nodes= ",adjacency.shape[0])
print("#compo= ",nx.number_connected_components(graph))
list_comp=sorted(nx.connected_components(graph), key = len, reverse=True)
print("#nodes in giant component= ", len(list_comp[0]))
print("percentage of nodes in main component= ",len(list_comp[0])/adjacency.shape[0])
# Out:
# #nodes=  3000
# #compo=  465
# #nodes in giant component=  2512
# percentage of nodes in main component=  0.8373333333333334

# %%
# list(nx.connected_component_subgraphs(graph))[0].node

# %%
#keep only the main component and corresponding label
conn_graph = list(nx.connected_component_subgraphs(graph))[0]
conn_label=label.iloc[list(list_comp[0])]

# %% [markdown]
# ## Graph plot##

# %%
laplacian=nx.laplacian_matrix(conn_graph)

# %%
# conn_label.label.genre['sub'].str.split("|",expand=True).iloc[:,0]

# %%
# conn_label.label.genre['sub'].str.split("|",expand=True).iloc[:,0].unique()

# %%
# for i,name in enumerate( conn_label.label.genre['sub'].str.split("|",expand=True).stack().value_counts().to_frame(name='count').reset_index()['index']):
#     label_num[label_num==name]=5*i
#     print(name," ",5*i)
# label_num[label_num>10]=0   
# conn_label.label.genre['sub'].str.split("|",expand=True).iloc[:,0]

# %%
label2=np.array(conn_label.label.genre.main)
# label2=np.array(conn_label.label.genre['sub'].str.split("|",expand=True).iloc[:,0]);
label_num=label2.copy()

for i,name in enumerate( conn_label.label.genre.main.unique()):
    label_num[label_num==name]=i
    print(name," ",i)
    
# label_num[label_num=='Rock']=0
# label_num[label_num=='Hip-Hop']=1
# label_num[label_num=='Folk']=4
# label_num[label_num=='Pop']=3
# label_num[label_num=='Experimental']=4
# label_num[label_num=='Electronic']=5
# label_num[label_num=='International']=6
# label_num[label_num=='Instrumental']=7

print(label_num)
# Out:
# Hip-Hop   0
# Folk   1
# Rock   2
# [0 0 1 ... 0 1 0]

# %%
e,eigenvectors = scipy.sparse.linalg.eigs(laplacian,k=6)

e=e.real
eigenvectors=eigenvectors.real

# %%
#using laplacian eigenmap
plt.figure(figsize=(8, 8))

plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], alpha=0.5, cmap='coolwarm')
plt.title('Feature/label vector as signal')
plt.xlabel('$U_1$')
plt.ylabel('$U_2$')
plt.show()

# %%
#using springlayout
coords = nx.spring_layout(conn_graph)  # Force-directed layout.

# %%
i=0
coords_x=[]
coords_y=[]
for i in (conn_graph.node):
    coords_x.append(coords[i][0])
    coords_y.append(coords[i][1]);   
    i+=1;

# %%
plt.figure(figsize=(15, 10))
nx.draw_networkx_nodes(conn_graph, coords,node_size=20, node_color=label_num)
# nx.draw_networkx_edges(conn_graph, coords, alpha=0.3)
sm = plt.cm.ScalarMappable( norm=plt.Normalize(vmin=np.min(label_num), vmax=np.max(label_num)))
sm._A = []
plt.colorbar(sm)
plt.show()

# %%
plt.figure(figsize=(15, 15))

plt.scatter(coords_x,coords_y,c=label_num , alpha=0.5, cmap='jet')

plt.colorbar()
plt.show()

# %%
tmp_label=list(np.array(conn_label.label.genre.main))

i=0;
node_dict=dict()
for n in conn_graph.node:
    node_dict[n]=i
    i+=1;
conn_graph_rename=nx.relabel_nodes(conn_graph,node_dict)

label_dict={i : tmp_label[i] for i in range(len(conn_graph.node))}
    
nx.set_node_attributes(conn_graph_rename, values=label_dict, name="genre")

# %%
# import random
# subnode=random.sample(list(conn_graph.node), 5000)
# sub_graph=conn_graph.subgraph(subnode)
nx.write_gexf(conn_graph_rename, "data/graph_small_HRFP.gexf")

# %%
# conn_graph_rename.node

# %% [markdown]
# # personal tests

# %%
dataSet
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             0.000812  0.001826  0.000140  0.000317  0.000465  0.000189
# 5             0.000060 -0.000027 -0.000157  0.000161  0.000608  0.000313
# 140           0.000060 -0.000218 -0.000611 -0.000254 -0.000240 -0.000026
# 141           0.000020 -0.000099 -0.000658 -0.000250 -0.000222 -0.000252
# 182           0.000034  0.000376 -0.000262  0.000034 -0.000098  0.000406
# 190          -0.000037 -0.000297 -0.000467 -0.000190 -0.000369 -0.000236
# 459                                   Krautrock
# 534                                        Folk
# 540                                        Folk
# 546                                        Folk
# 574                                        Punk
# 602                                        Folk
# 620                                        Folk
# 621                                        Folk
# 625                                        Folk
# 676                                     Hip-Hop
# 690                                        Rock
# ...                                         ...
# 149370                                      Rap
# 149416                     Rock|Punk|Rock Opera
# 149417                     Rock|Punk|Rock Opera
# 149452                               Industrial
# 149488                                    Metal
# 149523         Krautrock|Progressive|Space-Rock
# 149623                     Rap|Abstract Hip-Hop
# 149625                     Rap|Abstract Hip-Hop
# 149626                     Rap|Abstract Hip-Hop
# 149687                                  Hip-Hop
# 149689                                  Hip-Hop
# 149690                                  Hip-Hop
# 149951                                  Hip-Hop
# 149953                                  Hip-Hop
# 150062                   Folk|Singer-Songwriter
# 150063                   Folk|Singer-Songwriter
# 150064                   Folk|Singer-Songwriter
# 150287                                  Hip-Hop
# 150288                                  Hip-Hop
# 152543              Hip-Hop|Alternative Hip-Hop
# 152545              Hip-Hop|Alternative Hip-Hop
# 153337                              Hip-Hop|Rap
# 153946      Folk|Singer-Songwriter|British Folk
# 154303                Hip-Hop|Rap|Hip-Hop Beats
# 154305                Hip-Hop|Rap|Hip-Hop Beats
# 154306                Hip-Hop|Rap|Hip-Hop Beats
# 154307                Hip-Hop|Rap|Hip-Hop Beats
# 154308                Hip-Hop|Rap|Hip-Hop Beats
# 154309                Hip-Hop|Rap|Hip-Hop Beats
# 155066                    Hip-Hop|Hip-Hop Beats
#
# [3000 rows x 520 columns]

# %%
genre_top=genres[genres['parent']==0]
genre_top
# Out:
#           #tracks  parent                title  top_level
# genre_id
# 2            5271       0        International          2
# 3            1752       0                Blues          3
# 4            4126       0                 Jazz          4
# 5            4106       0            Classical          5
# 8             868       0  Old-Time / Historic          8
# 9            1987       0              Country          9
# 10          13845       0                  Pop         10
# 12          32923       0                 Rock         12
# 13            730       0       Easy Listening         13
# 14           1499       0             Soul-RnB         14
# 15          34413       0           Electronic         15
# 17          12706       0                 Folk         17
# 20           1876       0               Spoken         20
# 21           8389       0              Hip-Hop         21
# 38          38154       0         Experimental         38
# 1235        14938       0         Instrumental       1235

# %%
tracks_raw = pd.read_csv('../data/fma_metadata/raw_tracks.csv', index_col=0);
tracks_raw['track_url'][2]
# Out:
# 'http://freemusicarchive.org/music/AWOL/AWOL_-_A_Way_Of_Life/Food'

# %%
# find specific sample
samples=tracks[tracks['track']['genres']=='[15]']
samples_in_small=samples[samples['set']['subset'] == 'medium']
samples_in_small
# Out:
#             album                                            \
#          comments         date_created        date_released
# track_id
# 397             0  2009-01-07 11:04:01  2007-01-01 00:00:00
# 398             0  2008-11-26 02:01:54  2005-07-05 00:00:00
# 399             0  2008-11-26 02:01:54  2005-07-05 00:00:00
# 400             0  2009-01-07 11:04:01  2007-01-01 00:00:00
# 405             0  2008-11-26 02:01:54  2005-07-05 00:00:00
# 414             0  2008-11-26 02:01:54  2005-07-05 00:00:00
# 550             0  2008-11-26 02:08:19  2009-01-08 00:00:00
# 664             0  2008-11-26 02:14:23  2002-10-01 00:00:00
# 665             0  2009-01-08 12:05:17  2009-01-08 00:00:00
# 397                                     NaN         1   1697
# 398                                     NaN         0    122
# 399                                     NaN         0    122
# 400                                     NaN         1   1697
# 405                                     NaN         0    122
# 414                                     NaN         0    122
# 550                                     NaN         0    143
# 664                                     NaN         0    187
# 665                                     NaN         0   1707
# 878                                     NaN         1    242
# 881                                     NaN         0    243
# 889                                     NaN         1    242
# 1085                                    NaN         2    297
# 1086                                    NaN         2    297
# 1088                                    NaN         2    297
# 1089                                    NaN         2    297
# 1121                                    NaN         0    309
# 1339                                    NaN         0    345
# 1481                                    NaN         0    390
# 1483                                    NaN         0    390
# 1485                                    NaN         0    390
# 1486                                    NaN         0    389
# 1634                                    NaN         1    419
# 1635                                    NaN         1    419
# 1638                                    NaN         1    419
# 1640                                    NaN         1    419
# 1677                                    NaN         0    428
# 1678                                    NaN         0    428
# 3268                            Trent Wolbe         1    979
# 3452      Jason Sigal with Adrian Caballero         0    987
# ...                                     ...       ...    ...
# 145800                                  NaN         1  21785
# 145801                                  NaN         1  21785
# 145802                                  NaN         1  21785
# 145803                                  NaN         1  21785
# 145804                                  NaN         1  21785
# 145805                                  NaN         1  21785
# 147919                                  NaN         1  22050
# 147920                                  NaN         1  22050
# 147921                                  NaN         1  22050
# 147922                                  NaN         1  22050
# 147923                                  NaN         1  22050
# 147924                                  NaN         1  22050
# 148960                                  NaN         0  22199
# 148961                                  NaN         0  22199
# 148962                                  NaN         0  22199
# 151026                                  NaN         0  22505
# 151654                                  NaN         0  22571
# 152317                                  NaN         0  22625
# 152318                                  NaN         0  22625
# 152319                                  NaN         0  22625
# 152322                                  NaN         0  22626
# 152323                                  NaN         0  22626
# 152546                                  NaN         0  22646
# 152550                                  NaN         0  22646
# 152552                                  NaN         0  22646
# 152553                                  NaN         0  22646
# 152554                                  NaN         0  22646
# 152704                                  NaN         1  22662
# 152720                                  NaN         1  22663
# 152721                                  NaN         1  22663
#
#                                                                      \
#                                                 information listens
# track_id
# 397       <p>A 2CD collection of the unedited live perfo...    1931
# 398       <p>Back on the Tang gang with Dominic Cramp an...    6068
# 399       <p>Back on the Tang gang with Dominic Cramp an...    6068
# 400       <p>A 2CD collection of the unedited live perfo...    1931
# 405       <p>Back on the Tang gang with Dominic Cramp an...    6068
# 414       <p>Back on the Tang gang with Dominic Cramp an...    6068
# 550                                                     NaN    2918
# 664       <p><span style="font-family:'Courier New', Cou...    2565
# 665       <p><a href="http://www.ep.tc/music">http://www...    3879
# 878       <p>A series of unreleased mp3s available on th...    2172
# 881       <p>The latest unreleased recordings from Dan B...    2485
# 889       <p>A series of unreleased mp3s available on th...    2172
# 1085      <p>debut ep from Mahjongg on the (now defunct)...   15632
# 1086      <p>debut ep from Mahjongg on the (now defunct)...   15632
# 1088      <p>debut ep from Mahjongg on the (now defunct)...   15632
# 1089      <p>debut ep from Mahjongg on the (now defunct)...   15632
# 1121      <p>Davey Harms shows he is mastering his brand...    1429
# 1339      <p><em>Realistic Psychosis </em>is a cult expe...    1761
# 1481      <p>a now-out-of-print split EP with Endless Jo...    2258
# 1483      <p>a now-out-of-print split EP with Endless Jo...    2258
# 1485      <p>a now-out-of-print split EP with Endless Jo...    2258
# 1486      <p>Self-released tape recorded Alfred, NY and ...   61609
# 1634      <p>For this record, Snacks initially wanted to...    2365
# 1635      <p>For this record, Snacks initially wanted to...    2365
# 1638      <p>For this record, Snacks initially wanted to...    2365
# 1640      <p>For this record, Snacks initially wanted to...    2365
# 1677      <p>A home-recorded CDr from David Solomonoff a...    1936
# 1678      <p>A home-recorded CDr from David Solomonoff a...    1936
# 3268      <p>Angel Sanchez Borges makes a return visit t...    5725
# 3452      <p>Image: Chris Kalis (yellow), Dan Jugle (bot...    2603
# ...                                                     ...     ...
# 145800    <p>Fleslit is a producer (also known as Brando...   11214
# 145801    <p>Fleslit is a producer (also known as Brando...   11214
# 145802    <p>Fleslit is a producer (also known as Brando...   11214
# 145803    <p>Fleslit is a producer (also known as Brando...   11214
# 145804    <p>Fleslit is a producer (also known as Brando...   11214
# 145805    <p>Fleslit is a producer (also known as Brando...   11214
# 147919                                                  NaN    4896
# 147920                                                  NaN    4896
# 147921                                                  NaN    4896
# 147922                                                  NaN    4896
# 147923                                                  NaN    4896
# 147924                                                  NaN    4896
# 148960                                                  NaN    2581
# 148961                                                  NaN    2581
# 148962                                                  NaN    2581
# 151026                                                  NaN    1032
# 151654                                                  NaN    1892
# 152317                                                  NaN    1800
# 152318                                                  NaN    1800
# 152319                                                  NaN    1800
# 152322    <p><span style="color: #333333; font-family: '...    1546
# 152323    <p><span style="color: #333333; font-family: '...    1546
# 152546                                                  NaN    3578
# 152550                                                  NaN    3578
# 152552                                                  NaN    3578
# 152553                                                  NaN    3578
# 152554                                                  NaN    3578
# 152704                                                  NaN    1412
# 152720                                                  NaN    1792
# 152721                                                  NaN    1792
#
#                                        \
#              producer            tags
# track_id
# 397               NaN              []
# 398               NaN              []
# 399               NaN              []
# 400               NaN              []
# 405               NaN              []
# 414               NaN              []
# 550               NaN              []
# 664               NaN              []
# 665               NaN              []
# 878               NaN              []
# 881               NaN              []
# 889               NaN              []
# 1085              NaN              []
# 1086              NaN              []
# 1088              NaN              []
# 1089              NaN              []
# 1121              NaN              []
# 1339              NaN              []
# 1481              NaN              []
# 1483              NaN              []
# 1485              NaN              []
# 1486              NaN              []
# 1634              NaN              []
# 1635              NaN              []
# 1638              NaN              []
# 1640              NaN              []
# 1677              NaN              []
# 1678              NaN              []
# 3268         Liz Berg              []
# 3452      Jason Sigal              []
# ...               ...             ...
# 145800            NaN              []
# 145801            NaN              []
# 145802            NaN              []
# 145803            NaN              []
# 145804            NaN              []
# 145805            NaN              []
# 147919            NaN  ['electronic']
# 147920            NaN  ['electronic']
# 147921            NaN  ['electronic']
# 147922            NaN  ['electronic']
# 147923            NaN  ['electronic']
# 147924            NaN  ['electronic']
# 148960            NaN              []
# 148961            NaN              []
# 148962            NaN              []
# 151026            NaN              []
# 151654            NaN              []
# 152317            NaN              []
# 152318            NaN              []
# 152319            NaN              []
# 152322            NaN              []
# 152323            NaN              []
# 152546            NaN              []
# 152550            NaN              []
# 152552            NaN              []
# 152553            NaN              []
# 152554            NaN              []
# 152704            NaN              []
# 152720            NaN              []
# 152721            NaN              []
#
#                                 ...                               track  \
#                                 ...                         information
# track_id                        ...
# 397                             ...                                 NaN
# 398                             ...                                 NaN
# 399                             ...                                 NaN
# 400                             ...                                 NaN
# 405                             ...                                 NaN
# 414                             ...                                 NaN
# 550                             ...                                 NaN
# 664                             ...                                 NaN
# 665                             ...                                 NaN
# 878                             ...                                 NaN
# 881                             ...                                 NaN
# 889                             ...                                 NaN
# 1085                            ...                                 NaN
# 1086                            ...                                 NaN
# 1088                            ...                                 NaN
# 1089                            ...                                 NaN
# 1121                            ...                                 NaN
# 1339                            ...                                 NaN
# 1481                            ...                                 NaN
# 1483                            ...                                 NaN
# 1485                            ...                                 NaN
# 1486                            ...                                 NaN
# 1634                            ...                                 NaN
# 1635                            ...                                 NaN
# 1638                            ...                                 NaN
# 1640                            ...                                 NaN
# 1677                            ...                                 NaN
# 1678                            ...                                 NaN
# 3268                            ...                                 NaN
# 3452                            ...                                 NaN
# ...                             ...                                 ...
# 145800                          ...                                 NaN
# 145801                          ...                                 NaN
# 145802                          ...                                 NaN
# 145803                          ...                                 NaN
# 145804                          ...                                 NaN
# 145805                          ...                                 NaN
# 147919                          ...                                 NaN
# 147920                          ...                                 NaN
# 147921                          ...                                 NaN
# 147922                          ...                                 NaN
# 147923                          ...                                 NaN
# 147924                          ...                                 NaN
# 148960                          ...                                 NaN
# 148961                          ...                                 NaN
# 148962                          ...                                 NaN
# 151026                          ...                                 NaN
# 151654                          ...                                 NaN
# 152317                          ...                                 NaN
# 152318                          ...                                 NaN
# 152319                          ...                                 NaN
# 152322                          ...                                 NaN
# 152323                          ...                                 NaN
# 152546                          ...                                 NaN
# 152550                          ...                                 NaN
# 152552                          ...                                 NaN
# 152553                          ...                                 NaN
# 152554                          ...                                 NaN
# 152704                          ...                                 NaN
# 152720                          ...                                 NaN
# 152721                          ...                                 NaN
#
#                                  \
#          interest language_code
# track_id
# 397          3102            en
# 398          1957            en
# 399          1876            en
# 400          2864            en
# 405          1458            en
# 414          3930            en
# 550          2933            en
# 664          3510            en
# 665          4833            en
# 878          1238            en
# 881          2982            en
# 889          1464            en
# 1085          850            en
# 1086         1922            en
# 1088         1256            en
# 1089         1134            en
# 1121         3504            en
# 1339          516            en
# 1481         1529            en
# 1483         1082            en
# 1485         1615            en
# 1486         1541            en
# 1634          859            en
# 1635         1651            en
# 1638         1916            en
# 1640         1625            en
# 1677         1876            en
# 1678         3134            en
# 3268         3701            en
# 3452         2920            en
# ...           ...           ...
# 145800       1130           NaN
# 145801       1057           NaN
# 145802       1658           NaN
# 145803       1725           NaN
# 145804       2027           NaN
# 145805       2096           NaN
# 147919        742           NaN
# 147920        510           NaN
# 147921       2261           NaN
# 147922        522           NaN
# 147923        572           NaN
# 147924        813           NaN
# 148960        539           NaN
# 148961        682           NaN
# 148962        859           NaN
# 151026        953           NaN
# 151654        947           NaN
# 152317        941           NaN
# 152318        547           NaN
# 152319        665           NaN
# 152322        573           NaN
# 152323        673           NaN
# 152546        710           NaN
# 152550        652           NaN
# 152552        494           NaN
# 152553        480           NaN
# 152554        751           NaN
# 152704        752           NaN
# 152720       1071           NaN
# 152721        565           NaN
#
#                                                                               \
#                                                     license listens lyricist
# track_id
# 397       Attribution-NonCommercial-ShareAlike 3.0 Inter...     427      NaN
# 398       Attribution-NonCommercial-ShareAlike 3.0 Inter...     587      NaN
# 399       Attribution-NonCommercial-ShareAlike 3.0 Inter...     520      NaN
# 400       Attribution-NonCommercial-ShareAlike 3.0 Inter...     587      NaN
# 405       Attribution-NonCommercial-ShareAlike 3.0 Inter...     378      NaN
# 414       Attribution-NonCommercial-ShareAlike 3.0 Inter...    3737      NaN
# 550       Attribution-NonCommercial-NoDerivatives (aka M...    2632      NaN
# 664       Attribution-NonCommercial-ShareAlike 3.0 Inter...    1835      NaN
# 665       Attribution-NonCommercial-ShareAlike 3.0 Inter...    3870      NaN
# 878       Attribution-NonCommercial-ShareAlike 3.0 Inter...     571      NaN
# 881       Attribution-NonCommercial-ShareAlike 3.0 Inter...    2475      NaN
# 889       Attribution-NonCommercial-ShareAlike 3.0 Inter...     244      NaN
# 1085      Attribution-NonCommercial-ShareAlike 3.0 Inter...     450      NaN
# 1086      Attribution-NonCommercial-ShareAlike 3.0 Inter...     851      NaN
# 1088      Attribution-NonCommercial-ShareAlike 3.0 Inter...     405      NaN
# 1089      Attribution-NonCommercial-ShareAlike 3.0 Inter...     660      NaN
# 1121      Attribution-Noncommercial-Share Alike 3.0 Unit...    1432      NaN
# 1339      Attribution-NonCommercial-NoDerivatives (aka M...     431      NaN
# 1481      Attribution-Noncommercial-Share Alike 3.0 Unit...     600      NaN
# 1483      Attribution-Noncommercial-Share Alike 3.0 Unit...     416      NaN
# 1485      Attribution-Noncommercial-Share Alike 3.0 Unit...     372      NaN
# 1486      Attribution-Noncommercial-Share Alike 3.0 Unit...     386      NaN
# 1634      Attribution-Noncommercial-Share Alike 3.0 Unit...     364      NaN
# 1635      Attribution-Noncommercial-Share Alike 3.0 Unit...     602      NaN
# 1638      Attribution-Noncommercial-Share Alike 3.0 Unit...     588      NaN
# 1640      Attribution-Noncommercial-Share Alike 3.0 Unit...     323      NaN
# 1677      Attribution-Noncommercial-Share Alike 3.0 Unit...     184      NaN
# 1678      Attribution-Noncommercial-Share Alike 3.0 Unit...     174      NaN
# 3268      Attribution-NonCommercial-ShareAlike 3.0 Inter...    1283      NaN
# 3452      Attribution-NonCommercial-ShareAlike 3.0 Inter...     441      NaN
# ...                                                     ...     ...      ...
# 145800                                          Attribution     937      NaN
# 145801                                          Attribution     892      NaN
# 145802                                          Attribution    1336      NaN
# 145803                                          Attribution    1423      NaN
# 145804                                          Attribution    1709      NaN
# 145805                                          Attribution    1791      NaN
# 147919    Creative Commons Attribution-NonCommercial-NoD...     601      NaN
# 147920    Creative Commons Attribution-NonCommercial-NoD...     433      NaN
# 147921    Creative Commons Attribution-NonCommercial-NoD...    1642      NaN
# 147922    Creative Commons Attribution-NonCommercial-NoD...     437      NaN
# 147923    Creative Commons Attribution-NonCommercial-NoD...     488      NaN
# 147924    Creative Commons Attribution-NonCommercial-NoD...     658      NaN
# 148960    Attribution-Noncommercial-Share Alike 3.0 Unit...     442      NaN
# 148961    Attribution-Noncommercial-Share Alike 3.0 Unit...     550      NaN
# 148962    Attribution-Noncommercial-Share Alike 3.0 Unit...     714      NaN
# 151026    Creative Commons Attribution-NonCommercial-NoD...     760      NaN
# 151654    Creative Commons Attribution-NonCommercial-NoD...     731      NaN
# 152317                 Attribution-NonCommercial-ShareAlike     759      NaN
# 152318                 Attribution-NonCommercial-ShareAlike     483      NaN
# 152319                 Attribution-NonCommercial-ShareAlike     559      NaN
# 152322    Creative Commons Attribution-NonCommercial-NoD...     433      NaN
# 152323    Creative Commons Attribution-NonCommercial-NoD...     548      NaN
# 152546    Creative Commons Attribution-NonCommercial-NoD...     545      NaN
# 152550    Creative Commons Attribution-NonCommercial-NoD...     458      NaN
# 152552    Creative Commons Attribution-NonCommercial-NoD...     417      NaN
# 152553    Creative Commons Attribution-NonCommercial-NoD...     420      NaN
# 152554    Creative Commons Attribution-NonCommercial-NoD...     618      NaN
# 152704    Creative Commons Attribution-NonCommercial-NoD...     553      NaN
# 152720    Creative Commons Attribution-NonCommercial-NoD...     316      NaN
# 152721    Creative Commons Attribution-NonCommercial-NoD...     474      NaN
#
#                                            \
#          number publisher            tags
# track_id
# 397           4       NaN              []
# 398           1       NaN              []
# 399           2       NaN              []
# 400           5       NaN              []
# 405           3       NaN              []
# 414           8       NaN              []
# 550           0       NaN              []
# 664           6       NaN              []
# 665           0       NaN              []
# 878           5       NaN              []
# 881           1       NaN              []
# 889           3       NaN              []
# 1085          2       NaN              []
# 1086          3       NaN              []
# 1088          4       NaN              []
# 1089          5       NaN              []
# 1121          0       NaN              []
# 1339         14       NaN              []
# 1481          2       NaN              []
# 1483          3       NaN              []
# 1485          4       NaN              []
# 1486          4       NaN              []
# 1634          1       NaN              []
# 1635          4       NaN              []
# 1638          2       NaN              []
# 1640          7       NaN              []
# 1677          3       NaN              []
# 1678          4       NaN              []
# 3268          1       NaN              []
# 3452          1       NaN              []
# ...         ...       ...             ...
# 145800        0       NaN              []
# 145801        0       NaN              []
# 145802        0       NaN              []
# 145803        0       NaN              []
# 145804        0       NaN              []
# 145805        0       NaN              []
# 147919        1       NaN  ['electronic']
# 147920        2       NaN  ['electronic']
# 147921        3       NaN  ['electronic']
# 147922        4       NaN  ['electronic']
# 147923        5       NaN  ['electronic']
# 147924        6       NaN  ['electronic']
# 148960        4       NaN              []
# 148961        5       NaN              []
# 148962        6       NaN              []
# 151026        2       NaN              []
# 151654        3       NaN              []
# 152317        1       NaN              []
# 152318        2       NaN              []
# 152319        3       NaN              []
# 152322        3       NaN              []
# 152323        4       NaN              []
# 152546        1       NaN              []
# 152550        5       NaN              []
# 152552        7       NaN              []
# 152553        8       NaN              []
# 152554        9       NaN              []
# 152704        1       NaN              []
# 152720        7       NaN              []
# 152721        8       NaN              []
#
#
#                                                       title
# track_id
# 397                                       The Tides Of Land
# 398                             Borful Tang Loves Nomeansno
# 399                                                     ELI
# 400                                 Electronic Interlude VI
# 405                                        Majestic Shuffle
# 414                          John And Mary - The Restaurant
# 550                                        Cello Duet No. 1
# 664                                      side 6 - not funny
# 665                                       Disneyland (edit)
# 878                                       Bad Carnival Acid
# 881                                        I could be wrong
# 889                                               Wasteland
# 1085                                                 jamdek
# 1086                                countdown (the chicken)
# 1088                                               aluminum
# 1089                                  (bishop) desmond tutu
# 1121                                           Circle Crazy
# 1339                                     Emotional Accident
# 1481                                                  Cunca
# 1483                                                 Center
# 1485                                                Blaster
# 1486                                               Greeting
# 1634                                       Cabbage Disaster
# 1635              Odor Cameras From the Paris of the Future
# 1638           Doug's Username on Ebay: spaghetti van halen
# 1640                                                 Mother
# 1677              Miss Taznif Goes to Town Riding on a Pony
# 1678                                           A Simple Way
# 3268                                        Minimal Martini
# 3452                                             Air Jordan
# ...                                                     ...
# 145800                                            Crit Club
# 145801                                              Fleslit
# 145802                                           Freak Mode
# 145803                                                Paris
# 145804                                          Slack Track
# 145805                                  When the Rain Drops
# 147919                                         Hyperblaster
# 147920                                        Galactic Mist
# 147921                                         Happy Galaxy
# 147922                                             Zuzuland
# 147923                         Right Now Feat. Pizza Skitch
# 147924                                Ghost of the Wormhole
# 148960                                               Change
# 148961    Dusty Swamp Jives (Mystic Beats & Isaac Chambers)
# 148962    Lily Moon Feat. Jarrod Brereton (Instrumental ...
# 151026                                           Soma Haoma
# 151654                 In This Galaxy (Toxic Chicken remix)
# 152317                                              Gravity
# 152318                                               Sunset
# 152319                                        Symphonie See
# 152322                                          Toledo City
# 152323                                             Calm Dub
# 152546                                  Miniature Cassettes
# 152550                                           Moon Panda
# 152552                                         Wolf Indians
# 152553                                          Rural Magic
# 152554                                       Memory Guitars
# 152704                                             Evermore
# 152720                                           Moonquakes
# 152721                                             Aeronaut
#
# [1148 rows x 52 columns]

# %%
label['label']['genre']['main'].unique()
# Out:
# array(['Hip-Hop', 'Folk', 'Rock'], dtype=object)

# %%
G = graphs.Graph(nx.to_numpy_matrix(conn_graph))
G.compute_fourier_basis()
G.set_coordinates()

# %%
s = np.zeros(G.N)
DELTA = 100
s[DELTA]=1
tau = 100

# %%
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(2, 1, 1)
g = filters.Heat(G, tau, normalize=False)
s_out = g.filter(s, method='chebyshev')
s_out = s_out/max(s_out)
G.plot_signal(s_out, colorbar=True, ax=ax,vertex_size=15, highlight=[DELTA])

# %%
g.plot()

list_heat_neighbour = np.array([]).astype(int)

ind_max_heat = np.argsort(s_out)

np.append(list_heat_neighbour,ind_max_heat[-10:])
# Out:
# array([ 734,  140, 2111,  472, 1280, 1420, 2210, 1586,  786,  102],
#       dtype=int64)

# %%
musics_pos = [100,200,1000]

G = graphs.Graph(nx.to_numpy_matrix(conn_graph))
G.compute_fourier_basis()
G.set_coordinates()

playlist_len = 10;

tau = 100;
list_heat_neighbour = np.array([]).astype(int)
s_out_moy = np.zeros(G.N)

for i in musics_pos:
    s = np.zeros(G.N)
    s[i]=1
    
    g = filters.Heat(G, tau, normalize=False)
    s_out = g.filter(s, method='chebyshev')
    s_out = s_out/max(s_out)
    
    s_out_moy = s_out_moy + s_out
    
ind_max_heat = np.argsort(s_out_moy)
list_heat_neighbour=np.append(list_heat_neighbour,ind_max_heat[-playlist_len:])

# %%
list_heat_neighbour
# Out:
# array([1420, 1940, 2210, 1586,  728,  786,  102,  200, 1913, 2121],
#       dtype=int64)
